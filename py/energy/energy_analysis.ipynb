# %%
import pandas as pd
df = pd.read_pickle("../influx/data/shelly bathroom fan 2020-06-13 2021-12-23.pkl")
print(df)
# Out:
#                                    energy  power
# 2020-06-13 19:46:10.202554+00:00      NaN    0.0
# 2020-06-13 19:46:10.216677+00:00  25102.0    NaN
# 2020-06-13 19:46:17.406629+00:00      NaN    0.0
# 2020-06-13 19:46:17.419988+00:00  25102.0    NaN
# 2020-06-13 19:46:47.419047+00:00      NaN    0.0
# ...                                   ...    ...
# 2021-12-23 15:04:37.481304+00:00   7519.0    NaN
# 2021-12-23 15:05:07.626038+00:00      NaN    0.0
# 2021-12-23 15:05:07.635073+00:00   7519.0    NaN
# 2021-12-23 15:05:37.474596+00:00      NaN    0.0
# 2021-12-23 15:05:37.482657+00:00   7519.0    NaN
#
# [3244742 rows x 2 columns]

# %%
energy = df["energy"].dropna()
print(energy)
# Out:
# 2020-06-13 19:46:10.216677+00:00    25102.0
# 2020-06-13 19:46:17.419988+00:00    25102.0
# 2020-06-13 19:46:47.431605+00:00    25102.0
# 2020-06-13 19:47:17.450190+00:00    25102.0
# 2020-06-13 19:48:05.281009+00:00    25102.0
#                                      ...
# 2021-12-23 15:03:37.450109+00:00     7519.0
# 2021-12-23 15:04:07.463039+00:00     7519.0
# 2021-12-23 15:04:37.481304+00:00     7519.0
# 2021-12-23 15:05:07.635073+00:00     7519.0
# 2021-12-23 15:05:37.482657+00:00     7519.0
# Name: energy, Length: 1633159, dtype: float64

# %%
energy.plot()
# Out:
# <AxesSubplot:>
